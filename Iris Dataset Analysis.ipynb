# %% [markdown]
# The Iris flower has a large number of varieties. To this end, Ronald Fisher first created the Fisher's Iris dataset in 1936 in an attempt to be able to differentiate between three classes of Iris.
# We are taking data from these three classes of Iris, Iris Setosa, Iris Versicolour and Iris Virginica, these are very similar in shape compared to other Iris' species such as the Blue Bearded or the Dutch. The data set consists of 50 samples from each class of flower comprising of sepal length in cm, sepal width in cm, petal length in cm and petal width in cm for each class of Iris.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# In the next line I am assigning the name iris.data to the variable filename

# %%
Iris_Dataset = 'iris.data'

# %% [markdown]
# in the next line, I am assigning the contents of the iris.data file to the dataframe df. I am reading it in as a csv type document using the drop down list in VS code when I type in pd.read it gives me that option.

# %% [markdown]
# This is just to ensure I have the copy of a reference for when I am tidying up the project. https://www.geeksforgeeks.org/how-to-read-csv-file-with-pandas-without-header/

# %%
df = pd.read_csv(Iris_Dataset, header=None)
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# As the dataset had no column headers, I have to insert them into the dataset. I am using 0 to 4 for the numerical columns to make it easier for me later but using Iris as a column title for the flowers. I am saving the list of correct column names in a list called headers.

# %% [markdown]
# This is just to ensure I have the copy of a reference for when I am tidying up the project. https://www.geeksforgeeks.org/how-to-add-header-row-to-a-pandas-dataframe/ also Python Data Analysis with Iris Dataset | Data Science, plotting & graphing, https://www.youtube.com/watch?v=02BFXhPQWHQ

# %%
df.set_axis([0, 1, 2, 3, "Iris"], axis=1,inplace=True)
headers = ["sepal length", "sepal width", "petal length", "petal width"]
df
# Out:
#        0    1    2    3            Iris
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# using the command describe, I can see the statistical details of the data, but this shows the statistical data across all three types of iris.

# %%
print(df.describe())
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# This is just a check that I have all the data correctly stored, I am checking how many rows for each species

# %% [markdown]
# This is just to ensure I have the copy of a reference for when I am tidying up the project. FROM Python Data Analysis with Iris Dataset | Data Science, plotting & graphing, https://www.youtube.com/watch?v=02BFXhPQWHQ

# %%
df.Iris.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Iris, dtype: int64

# %% [markdown]
# show a histogram of just the sepal length values

# %%
plt.hist(df[0])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# printing a histogram of all the values with labels to the chart. I am using the headers list I created earlier to add the labels

# %%
plt.hist([df[0], df[1], df[2], df[3]], label=[headers[0], headers[1], headers[2], headers[3]])
plt.legend()

# %% [markdown]
# The histogram below shows two values, sepal length and sepal width, the transparency has been changed so that where one is behind the other, I can still see the data

# %%
plt.hist(df[0], alpha = 1)
plt.hist(df[1], alpha = 0.5)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# The histogram below shows two values, petal length and petal width, the transparency has been changed so that where one is behind the other, I can still see the data

# %%
plt.hist(df[2], alpha = 1)
plt.hist(df[3], alpha = 0.5)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Showing a comparison of the 4 histograms clearly showing the length and width categories

# %%
fig, ax=plt.subplots(2, 2, figsize=(8, 4))
ax[0,0].hist(df[0])
ax[0,1].hist(df[1])
ax[1,0].hist(df[2])
ax[1,1].hist(df[3])
ax[0,0].set_title(headers[0])
ax[0,1].set_title(headers[1])
ax[1,0].set_title(headers[2])
ax[1,1].set_title(headers[3])
# Out:
# Text(0.5, 1.0, 'petal width')

# %% [markdown]
# The scatter plot below shows two values, sepal length and sepal width, three colours are used to differentiate the flower types

# %%
colour = {'Iris-setosa':'red', 'Iris-virginica':'green', 'Iris-versicolor':'blue'}
plt.scatter(df[0], df[1], c=df['Iris'].map(colour))
plt.xlabel(headers[0])
plt.ylabel(headers[1])
plt.savefig("Scatter Sepal")

# %% [markdown]
# The scatter plot below shows two values, petal length and petal width, three colours are used to differentiate the flower types

# %%
plt.scatter(df[2], df[3], c=df['Iris'].map(colour))
plt.xlabel(headers[2])
plt.ylabel(headers[3])
plt.savefig("Scatter Petal")

# %% [markdown]
# This table shows the correlation between the lengths and widths of each flower

# %%
df.corr()
# Out:
#           0         1         2         3
# 0  1.000000 -0.109369  0.871754  0.817954
# 1 -0.109369  1.000000 -0.420516 -0.356544
# 2  0.871754 -0.420516  1.000000  0.962757
# 3  0.817954 -0.356544  0.962757  1.000000

# %% [markdown]
# I am using a box plot to show the range of values in the width and length columns.

# %% [markdown]
# ref https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.plotting.boxplot.html

# %%
plt.boxplot([df[0], df[1], df[2], df[3]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cfdfa21d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cfdfa21e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cfdfa21a60>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1cfdfa21f70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1cfdf7bcfd0>,
# ...
#  'means': []}

# %%
df.boxplot(column=[0, 1, 2, 3], by =['Iris'])
plt.savefig("Boxplot")

# %% [markdown]
# I differentiate the data by flower again using a boxplot, using the data for the sepal length column

# %%
df.boxplot(column=[0], by=['Iris'])
# Out:
# <AxesSubplot:title={'center':'0'}, xlabel='[Iris]'>

# %% [markdown]
# To improve the comparison of the data, the four columns of data are shown on this next boxplot

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))
Sepal_Length = [df[0][df.Iris == 'Iris-setosa'], df[0][df.Iris == 'Iris-virginica'], df[0][df.Iris == 'Iris-versicolor']]
Sepal_Width = [df[1][df.Iris == 'Iris-setosa'], df[1][df.Iris == 'Iris-virginica'], df[1][df.Iris == 'Iris-versicolor']]
Petal_Length = [df[2][df.Iris == 'Iris-setosa'], df[2][df.Iris == 'Iris-virginica'], df[2][df.Iris == 'Iris-versicolor']]
Petal_Width = [df[3][df.Iris == 'Iris-setosa'], df[3][df.Iris == 'Iris-virginica'], df[3][df.Iris == 'Iris-versicolor']]

ax[0, 0].boxplot(Sepal_Length, widths = 0.7)
ax[0, 0].set_title(headers[0])
ax[0, 1].boxplot(Sepal_Width, widths = 0.7)
ax[0, 1].set_title(headers[1])
ax[1, 0].boxplot(Petal_Length, widths = 0.7)
ax[1, 0].set_title(headers[2])
ax[1, 1].boxplot(Petal_Width, widths = 0.7)
ax[1, 1].set_title(headers[3])
# Out:
# Text(0.5, 1.0, 'petal width')

# %%
fig, ax = plt.subplots()
def colour(plot):
    plt.setp(plot['boxes'][0], color='blue')
    plt.setp(plot['boxes'][1], color='red')
    plt.setp(plot['boxes'][2], color='green')

Sepal_Length = [df[0][df.Iris == 'Iris-setosa'], df[0][df.Iris == 'Iris-virginica'], df[0][df.Iris == 'Iris-versicolor']]
Sepal_Width = [df[1][df.Iris == 'Iris-setosa'], df[1][df.Iris == 'Iris-virginica'], df[1][df.Iris == 'Iris-versicolor']]
Petal_Length = [df[2][df.Iris == 'Iris-setosa'], df[2][df.Iris == 'Iris-virginica'], df[2][df.Iris == 'Iris-versicolor']]
Petal_Width = [df[3][df.Iris == 'Iris-setosa'], df[3][df.Iris == 'Iris-virginica'], df[3][df.Iris == 'Iris-versicolor']]

plot = plt.boxplot(Sepal_Length, positions = [1, 2, 3], widths = 0.7)
colour(plot)
plot = plt.boxplot(Sepal_Width, positions = [5, 6, 7], widths = 0.7)
colour(plot)
plot = plt.boxplot(Petal_Length, positions = [9, 10, 11], widths = 0.7)
colour(plot)
plot = plt.boxplot(Petal_Width, positions = [13, 14, 15], widths = 0.7)
colour(plot)

ax.set_xticks([2, 6, 10, 14])
ax.set_xticklabels(headers)
ax.set_title('Boxplots by Iris')
ax.legend([plot["boxes"][0], plot["boxes"][1],plot["boxes"][2]], ['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'], loc='upper right')
plt.show()

# %% [markdown]
# Trying to put all boxplots on one graph with labels

# %% [markdown]
# ref https://stackoverflow.com/questions/47528955/adding-a-legend-to-a-matplotlib-boxplot-with-multiple-plots-on-same-axes

# %%
fig, ax = plt.subplots()
def set_colour(plot):
    plt.setp(plot['boxes'][0], color='blue')
    plt.setp(plot['boxes'][1], color='red')
    plt.setp(plot['boxes'][2], color='green')

A = [df[0][df.Iris == 'Iris-setosa'], df[0][df.Iris == 'Iris-virginica'], df[0][df.Iris == 'Iris-versicolor']]
B = [df[1][df.Iris == 'Iris-setosa'], df[1][df.Iris == 'Iris-virginica'], df[1][df.Iris == 'Iris-versicolor']]
C = [df[2][df.Iris == 'Iris-setosa'], df[2][df.Iris == 'Iris-virginica'], df[2][df.Iris == 'Iris-versicolor']]
D = [df[3][df.Iris == 'Iris-setosa'], df[3][df.Iris == 'Iris-virginica'], df[3][df.Iris == 'Iris-versicolor']]

plot = plt.boxplot(A, positions = [1, 2, 3], widths = 0.7)
set_colour(plot)
plot = plt.boxplot(B, positions = [5, 6, 7], widths = 0.7)
set_colour(plot)
plot = plt.boxplot(C, positions = [9, 10, 11], widths = 0.7)
set_colour(plot)
plot = plt.boxplot(D, positions = [13, 14, 15], widths = 0.7)
set_colour(plot)

ax.set_xticks([2, 6, 10, 14])
ax.set_xticklabels(headers)
ax.set_title('Boxplots by Iris')
ax.legend([plot["boxes"][0], plot["boxes"][1], plot["boxes"][2]], ['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'], loc='upper right')
plt.show()

# %% [markdown]
# Open a file named test, write the dataframe data to the file but convert it to a string first.

# %% [markdown]
# ref https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_string.html

# %%
filename = "test.txt"
with open(filename, 'wt') as f:
    f.write(df.to_string())
